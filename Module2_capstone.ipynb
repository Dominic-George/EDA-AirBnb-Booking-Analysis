# %% [markdown]
# <a href="https://colab.research.google.com/github/Dominic-George/EDA-AirBnb-Booking-Analysis/blob/main/Module2_capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/AirBnb Booking Analysis
# ##### **Contribution**    - Individual
# ##### **Dominic George**

# %% [markdown]
# # **Project Summary**    -

# %% [markdown]
# In the dynamic urban landscape of New York City, Airbnb has transformed the hospitality sector, offering travelers diverse lodging options and providing hosts with profitable opportunities. This project focuses on an extensive Exploratory Data Analysis (EDA) of the Airbnb NYC 2019 dataset, aiming to unveil insights into the intricacies of listing trends, host activities, and guest preferences in one of the world’s most iconic cities.
#
# The dataset we analyze is rich with information from Airbnb listings across New York City for the year 2019. It includes a wide range of attributes such as listing details, host information, neighborhood data, and booking statistics. Our goal is to explore these attributes to gain a thorough understanding of the factors influencing the Airbnb market in New York City.
#
# We begin our exploration by analyzing basic statistics and distributions of key numeric variables within the dataset. Key variables of interest include listing prices, minimum nights required for booking, number of reviews, and listing availability. We use box plots, pie charts, scatter plots etc. to visualize the distribution of these variables and identify central tendencies, spreads, and potential outliers.
#
# We explored the relationships between different variables through correlation analysis. Using scatter plots, pair plots, and correlation matrices, we seek to uncover patterns and dependencies among variables. For example, we investigate correlations between listing prices and availability, number of reviews and host listings count, and other relevant factors.
#
# Correlation matrices provide a comprehensive view of how strongly variables are related. For example, a high positive correlation between the number of reviews and listing prices might indicate that higher-priced listings tend to receive more reviews, possibly due to greater exposure or higher guest satisfaction.
#
# Understanding spatial patterns is crucial for assessing the distribution of listings across various neighborhoods and boroughs of New York City. We use heatmaps, and box plots with respect to areas and groups for geographical visualizations to examine how listings are spread out and how factors like average prices and popularity vary across different locations.
#
# For instance, heatmaps can reveal areas with high concentrations of listings or higher average prices, helping identify popular or underserved regions. This spatial analysis provides valuable insights into market dynamics and geographical disparities in listing characteristics.
#
# To uncover patterns related to booking behavior, we analyze temporal dynamics and seasonality by examining booking availability and review counts over time. We use various techniques to explore fluctuations in booking activity throughout the year.
#
# Our EDA of the Airbnb NYC 2019 dataset provides a comprehensive view of the Airbnb market dynamics in New York City. By examining trends, relationships, and patterns within the data, we offer valuable insights that support informed decision-making for hosts and enhance the overall guest experience. This analysis contributes to a deeper understanding of the Airbnb ecosystem, helping stakeholders navigate the vibrant and complex landscape of New York City's hospitality industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Dominic-George/EDA-AirBnb-Booking-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The New York City Airbnb market is a vibrant, quickly changing ecosystem that offers a range of opportunities and challenges to business stakeholders, legislators, hosts, and guests. In order to properly navigate this complicated landscape, a thorough analysis of the Airbnb NYC 2019 dataset is required in order to unearth insights and solve important concerns pertaining to the dynamics of the market. In order to improve understanding and guide decision-making, our problem statement centres on examining trends, behaviours, preferences, and spatial-temporal patterns within the Airbnb ecosystem.
#
# Within the context of the New York City Airbnb market, the analysis aims to address basic questions regarding host behaviours, guest preferences, spatial dynamics, temporal fluctuations, and policy implications. It is essential for both hosts and visitors to comprehend how listing pricing, availability, and demand change over time and throughout neighbourhoods in order to maximise their approaches and experiences. Insights into host behaviours and market competitiveness can also be gained by examining host features, such as the quantity of listings managed and their relationship to listing popularity and pricing tactics.
#
# Enhancing guest pleasure and experience also requires learning about guest preferences, which include elements that affect reservations such room type, location, and amenities. By illuminating neighbourhood dynamics, listing characteristics, and pricing dynamics, spatial analysis provides insightful information on geographic trends and inequalities. In addition, temporal dynamics analysis offers hosts and policymakers practical insights through the examination of seasonal trends, peak periods, and events that influence pricing and demand.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to harness insights from the Airbnb NYC 2019 dataset to refine strategic decision-making, enhance operational efficiencies, and improve overall user experience within the Airbnb ecosystem in New York City. Our goal is to achieve a range of specific business objectives that benefit hosts, guests, regulators, and industry stakeholders.
#
# Firstly, we aim to provide hosts with data-driven insights into market trends, competitive pricing strategies, and guest preferences. By analyzing demand patterns and market positioning, hosts can tailor their listing strategies to boost occupancy rates and revenue. Additionally, by offering guests detailed information on listing features, neighborhood amenities, and local attractions, we enhance their booking experiences and increase satisfaction, which in turn can lead to more positive reviews and repeat bookings.
#
# Furthermore, this project seeks to offer valuable insights to policymakers and regulatory authorities regarding the effects of Airbnb on housing markets, neighborhood dynamics, and community welfare. By presenting evidence-based findings, we aim to assist in crafting balanced regulatory policies that address the needs of hosts, guests, and the broader community, fostering responsible participation in the Airbnb ecosystem and supporting sustainable urban development.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Libraries
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Dataset Duplicate Value Count
#creating a empty dictionary
duplicates_by_column = {}

for column in df.columns:
    duplicates_count = df[column].duplicated().sum()
    duplicates_by_column[column] = duplicates_count

print("Number of duplicate values for each column:")
print(duplicates_by_column)
# Out:
# Number of duplicate values for each column:
# {'id': 0, 'name': 989, 'host_id': 11438, 'host_name': 37442, 'neighbourhood_group': 48890, 'neighbourhood': 48674, 'latitude': 29847, 'longitude': 34177, 'room_type': 48892, 'price': 48221, 'minimum_nights': 48786, 'number_of_reviews': 48501, 'last_review': 47130, 'reviews_per_month': 47957, 'calculated_host_listings_count': 48848, 'availability_365': 48529}

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
number_of_missig_values= df.isna().sum()
number_of_missig_values
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msn
msn.bar(df)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on the aforementioned procedures, we can deduce that the dataset consists of 48895 rows and 16 columns with null values in the majority of the columns as well as certain columns with no null values.
# The columns with the greatest null values are last_review and reviews_per_month.The only column with zero duplicate values is the column id.Additionally, some of the columns have missing values,the columns with the greatest amount of missing values are last_review and reviews_per_month.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1-id: unique identifier assigned to each Airbnb listing.\
# 2-name: title given to the Airbnb listing.\
# 3-host_id: unique identifier for the host of the listing.\
# 4-host_name: name of the host managing the listing.\
# 5-neighbourhood_group: group of neighborhoods categorized by administrative boundaries (e.g., district,city).\
# 6-neighbourhood: specific neighborhood where the listing is situated.\
# 7-latitude: geographic latitude coordinates of the listing.\
# 8-longitude: geographic longitude coordinates of the listing.\
# 9-room_type: type of accommodation offered in the listing (e.g., entire home/apartment, private room, shared room).\
# 10-price: nightly rate charged for booking the listing.\
# 11-minimum_nights: minimum number of nights required for booking the listing.\
# 12-number_of_reviews: total count of reviews provided for the listing.\
# 13-last_review: date when the last review was submitted for the listing.\
# 14-reviews_per_month: average number of reviews received per month for the listing.\
# 15-calculated_host_listings_count: total number of listings managed by the host on Airbnb.\
# 16-availability_365: number of days in a year that the listing is available for booking.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
  unique_values=df[column].unique()
  print(f"The unique values of the column, '{column}' is:")
  print(unique_values)
# Out:
# The unique values of the column, 'id' is:
# [    2539     2595     3647 ... 36485431 36485609 36487245]
# The unique values of the column, 'name' is:
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# The unique values of the column, 'host_id' is:
# [     2787      2845      4632 ... 274321313  23492952  68119814]
# The unique values of the column, 'host_name' is:
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# The unique values of the column, 'neighbourhood_group' is:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# The unique values of the column, 'neighbourhood' is:
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
values_to_fill={'name':'no name','host_name':'no hostname'}
df.fillna(value=values_to_fill,inplace=True)

# %%
#droping this columns from the dataset
columns_to_drop = ['latitude', 'longitude', 'last_review','reviews_per_month']
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
#printing the column names after dropping the necessary columns.
column_names=df.columns.tolist()
print(column_names)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood        room_type  \
# 0         John            Brooklyn          Kensington     Private room
# 1     Jennifer           Manhattan             Midtown  Entire home/apt
# ...

# %%
# Again checking for null values in the dataset to conform that there are no null values in the data set.
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.shape
# Out:
# (48895, 12)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# First, I changed the missing values that were present in the "name" and "hostname" columns to no name and no hostname respectively and I eliminated the less important latitude and longitude columns in the following phase. I also eliminated the columns last_review and review_per_month, which have a lot of missing values.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#First calculate the averege price by neighbourhood_group
#performing the groupby operation for neighbourhood_group and price columns
nh_group_avg_price=df.groupby('neighbourhood_group')['price'].mean()
#sorting in descending order
nh_group_avg_price_sorted=nh_group_avg_price.sort_values(ascending=False)
print(nh_group_avg_price_sorted)
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
# Plotting the figure
plt.figure(figsize=(10, 6))
# Plotting the bar chart
nh_group_avg_price_sorted.plot(kind='bar', color='grey')

# Adding titles and labels
plt.title('Average Price by Neighbourhood Group',fontsize=16)
plt.xlabel('Neighbourhood Group',fontsize=15,color='indigo')
plt.ylabel('Price',fontsize=15,color='indigo')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(nh_group_avg_price_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason I chose this specific chart is that vertical bar charts are the most effective way to depict or illustrate comparisons between groups or categories.If it is further arranged in ascending order, it will be simpler for the observer to determine the outcome or gain the insight, which is the highest percentage in relation to the local community.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The figure above offers a plethora of information, some of which are enumerated below.
# 1. **The chart primarily depicts the areas that need to be improved or enhanced in order to boost both pricing and profit.**
# 2. The cost varies depending on the city or neighborhood,it is inevitable that some of the more well-known cities have quite expensive costs.
# 3. It is possible that less expensive neighborhoods may have less opulent or high-quality real estate, or that there may be very little demand in those less well-known locations.
# 4. The population density of the well-known cities may be the cause of their high prices,as demand rises with a high population, so does the cost.
# 5. The price is also determined by the location, whether it is a developed area, a tourism area, or other relevant locations.
# 6. Neighborhood groups with higher average prices might be considered as luxurious areas, while those with lower average prices may be perceived as more affordable areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gathered insights aid to create a positive business impact because businessmen and investors will have a clear understanding of where they need to focus, invest, or improve.\
# For an average person, this information is only useful in finding rental houses that meet his price requirements.\
# There are no insights that have a negative influence or cause growth because the chart provides precise information about price variances and areas that need to be improved so that the firm can thrive.\
# However, neglecting or failing to focus on important areas may result in negative growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#performing the groupby operations for host_name,neighbourhood_group and finding which host has more bookings or counts.We are using neighbourhood_group since there are simlilar names in different neighbourhood groups.
listings_count = df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
#sorting the values in descending order
sorted_listings_count = listings_count.sort_values(by='calculated_host_listings_count', ascending=False)
sorted_listings_count.head(10)
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1833          Blueground            Brooklyn                             232
# 1834          Blueground           Manhattan                             232
# 7275                Kara           Manhattan                             121
# 7479              Kazuya           Manhattan                             103
# 7480              Kazuya              Queens                             103
# 7478              Kazuya            Brooklyn                             103
# 6540      Jeremy & Laura           Manhattan                              96
# 13216             Sonder           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %%
# Create a new column combining host_name and neighbourhood_group
sorted_listings_count['neighbourhood__group'] = sorted_listings_count['host_name'] + '-(' + sorted_listings_count['neighbourhood_group'] + ')'

# Plot the data
plt.figure(figsize=(12, 6))
bars = plt.bar(sorted_listings_count['neighbourhood__group'][:10],
               sorted_listings_count['calculated_host_listings_count'][:10],
               color='grey')
plt.xlabel('Name of the host and neighbourhood group',fontsize=15,color='indigo')
plt.ylabel('Maximum listings Count',fontsize=15,color='indigo')
plt.title('Top 10 Hosts with the Most Listings in Each Neighbourhood Group',fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add the listing count values on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, int(yval), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
host_with_most_listings = df.groupby(['host_name','neighbourhood_group','calculated_host_listings_count','room_type'])['price'].sum()
#sorting the values in descending order
host_with_most_listings_sorted = host_with_most_listings.sort_values(ascending=False)
host_with_most_listings_sorted.head()
# Out:
# host_name     neighbourhood_group  calculated_host_listings_count  room_type
# Sonder (NYC)  Manhattan            327                             Entire home/apt    80360
# Blueground    Manhattan            232                             Entire home/apt    69741
# Red Awning    Manhattan            49                              Entire home/apt    35294
# Kara          Manhattan            121                             Entire home/apt    33581
# Sally         Manhattan            12                              Entire home/apt    29194
# Name: price, dtype: int64

# %%
# Plotting the figure
top_hosts = host_with_most_listings_sorted.head(10)  # Adjust the number as needed

# Convert Series to DataFrame for easier plotting
top_hosts_df = top_hosts.reset_index()

# Create a column chart
plt.figure(figsize=(12, 8))
plt.bar(top_hosts_df.index, top_hosts_df['price'], color='grey')
plt.xlabel('Host Index', fontsize=14,color='indigo')
plt.ylabel('Total Price', fontsize=14,color='indigo')
plt.title('Top 10 Hosts by Total Price of Listings', fontsize=16)
plt.xticks(top_hosts_df.index, top_hosts_df['host_name'] + ' (' + top_hosts_df['neighbourhood_group'] + ')', rotation=45,ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason I chose this specific chart is that vertical bar charts are the most effective way to depict or illustrate comparisons between groups or categories.If it is further arranged in ascending order, it will be simpler for the observer to determine the outcome or gain the insight regarding who has the most listings with respect to the neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By looking at the above graph, we can understand who has more listings with respect to the neighbourhood group; furthermore, we can identify the people who have fewer listings or who are laging behind in the business.
#
# Further looking into the next graph we can observe who has more profit  considering the total listings and price with respect to the neighbourhood group, and room type and  it helps in calculating the profit by user and summing up the price will give the profit. \
# Here, taking the average of the price is not applicable since there are some properties with just one or two listings. By taking the sum, we get the total amount that can be collected with the given listings and price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, suggestions can be given to those people who are laging behind, to improve their business by implementing various strategies to increase their customers. Suggestions like advertisement campaigns, discounts while renting the property or others measures can be implemented to improve the business.
# No insights that lead to negative growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
roomtype_avg_price=df.groupby('room_type')['price'].mean()
#sorting in descending order
roomtype_avg_price_sorted=roomtype_avg_price.sort_values(ascending=False)
print(roomtype_avg_price_sorted)
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
# Plotting the figure
plt.figure(figsize=(8, 5))

# Plotting the bar chart
roomtype_avg_price_sorted.plot(kind='bar', color='grey')

# Adding titles and labels
plt.title('Average Price by Neighbourhood Group')
plt.xlabel('Room type',fontsize=12,color='indigo')
plt.ylabel('Price',fontsize=12,color='indigo')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(roomtype_avg_price_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose the vertical bar graph since it is used for showing comparisons between categories or groups, and it is easier to see the comparisons or the data that is illustrated in the graph, which is the average price with respect to different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph shows the average price of the properties irrespective of the location with respect to the three main room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Since the graph only includes the average price, it doesn't add any positive or negative growth towards the business but helps to keep track of the price.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#performing the groupby operations for host_name,neighbourhood_group and finding which host has more bookings or counts.We are using neighbourhood_group since there are simlilar names in different neighbourhood groups.
name_vs_availability = df.groupby(['room_type'])['availability_365'].mean().reset_index()
#sorting the values in descending order
sorted_name_vs_availability = name_vs_availability.sort_values(by='availability_365', ascending=False)
sorted_name_vs_availability.head(10)
# Out:
#          room_type  availability_365
# 2      Shared room        162.000862
# 0  Entire home/apt        111.920304
# 1     Private room        111.203933

# %%
import matplotlib.pyplot as plt

# Example data preparation (replace with your actual data)
labels = sorted_name_vs_availability['room_type'][:10]
sizes = sorted_name_vs_availability['availability_365'][:10]

plt.figure(figsize=(10, 6))
bars = plt.bar(labels, sizes, color='grey')
plt.xlabel('Room Type',fontsize=12,color='indigo')
plt.ylabel('Availability (days)',fontsize=12,color='indigo')
plt.title('Room Type vs Availability across all neighbourhood groups')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this particular chart because, in my opinion, vertical bar charts are the best for showing or illustrating comparisons across groups or categories.It will be easier for the observer to ascertain the result or obtain the insight—that is, the availability of the room in relation to the type of room—if it is further organised in ascending order.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here the graph shows the availability of the rooms with respect to their room type throughout a year. Here we can observe that on average the shared room is available for about 162 days in a year, even though the average price of the shared room is very low when compared to the other room types. This means it can be considered that the room is not engaged in most of the days in a year. This may be due to various reasons. On the other hand, both the entire home and the private room are available for almost 111 in a year, which means they are more engaged when compared to the shared room.
# It can be considered that people are more interested in a trip with their family members or all alone.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the insights helps in creating a positive business impact.\
# Here we can see where the business is laging, and it helps us take actions in order to improve the number of customers in that area or to improve the business. Various strategies can be taken to improve the business.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,6))
plt.scatter(df['price'],df['number_of_reviews'],color='indigo')
plt.xlabel('Price',fontsize=12)
plt.ylabel('Number of reviews',fontsize=12)
plt.title('Number of reviews vs price',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason to select this specific chart is that the scatter plot is used to show the relationships between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph, the number of reviews can be considered as the number of checkins or the number of people who stayed in that property. It is evident from the graph that there are more reviews for the properties that have a lower price, or it can be said that lower the price, higher the number of people who stayed in that particular property.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the insights helps in creating a positive business impact.\
# It can also be considered that people who opt properties with higher price didnt give reviews because of many reasons it may include lack of facilities, lack of good service, poor infrastructure or various other reasons.Measures can be taken to improve the situation by analysing the needs of the customers.
# Another point to be noted is that there is a possibilty that less people selected properties which have higher price.
# The number of reviews is important since it helps in analysing the do's and dont's.
#
# The negatives can be considered as lack of facilities, lack of good service, poor infrastructure or various other reasons that have resulted in the poor performance of the expensive properties.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
room_type_counts = df['room_type'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are useful for comparing the components of a whole or for displaying the relative proportions of a group of numbers, which is why I used one here. The distribution of room types over the whole data set is displayed here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is clear from the graph that numerous properties are available for full-time rental. This might be because there is a need for full-service properties, of which private rooms are the second most popular kind.\
# Demand for shared rooms is lower, so there are fewer options available.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the insights helps in creating a positive business impact.\
#  Since there are only a few options for shared rooms, it is an area that can be improved. There may be various reasons for its fewer options and demand. Various measures can be taken to change the scenario and make it boom.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
price_room_type_neigh_group=df.groupby(['neighbourhood_group','room_type'])['price'].max().reset_index()
sorted_price_room_type_neigh_group=price_room_type_neigh_group.sort_values(by='price',ascending=False)
sorted_price_room_type_neigh_group.head(10)
# Out:
#    neighbourhood_group        room_type  price
# 3             Brooklyn  Entire home/apt  10000
# 6            Manhattan  Entire home/apt  10000
# 10              Queens     Private room  10000
# 7            Manhattan     Private room   9999
# 4             Brooklyn     Private room   7500
# 12       Staten Island  Entire home/apt   5000
# 9               Queens  Entire home/apt   2600
# 1                Bronx     Private room   2500
# 11              Queens      Shared room   1800
# 0                Bronx  Entire home/apt   1000

# %%
#selecting top 10
top_10 = sorted_price_room_type_neigh_group.head(10)
top_10['count'] = top_10['neighbourhood_group'] + '-(' + top_10['room_type'] + ')'

# Plotting the bar plot
plt.figure(figsize=(10, 6))
barss = plt.bar(range(len(top_10)), top_10['price'], color='grey')
plt.xlabel('Combination (Neighbourhood Group - Room Type)', fontsize=12, color='indigo')
plt.ylabel('Maximum Price', fontsize=12, color='indigo')
plt.title('Top 10 Combinations with Highest Maximum Prices')
plt.xticks(range(len(top_10)), top_10['count'], rotation=60,ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Adding labels on top of each bar
for bar in barss:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom', fontsize=9)
plt.show()
# Out:
# <ipython-input-21-bdb6769e0dc6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10['count'] = top_10['neighbourhood_group'] + '-(' + top_10['room_type'] + ')'

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason I chose this specific chart is that vertical bar charts are the most effective way to depict or illustrate comparisons between groups or categories.If it is further arranged in ascending order, it will be simpler for the observer to determine the outcome or gain the insight regarding the top ten expensive combinations with respect to the neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart depicts the top ten expensive room types with respect to the neighbourhood group. It is clear from the graph that there are variations for different types of rooms, it differs in different cities or areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the gained insights helps in creating a positive business impact.\
# To improve the customers, one can implement various strategies to make people select the expensive ones that are attached to a particular area to gain more profit or do some campaigns to promote the less expensive ones.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
most_reviews=df.groupby('room_type')['number_of_reviews'].sum()
#sorting in descending order
most_reviews_sorted=most_reviews.sort_values(ascending=False)
print(most_reviews_sorted)
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %%
# Plotting the figure
plt.figure(figsize=(10, 6))
# Plotting the bar chart
most_reviews_sorted.plot(kind='bar', color='grey')

# Adding titles and labels
plt.title('Room types with most reviews')
plt.xlabel('Roomtype',fontsize='12',color='indigo')
plt.ylabel('Number of reviews',fontsize='12',color='indigo')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(most_reviews_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %%
# Chart - 8 visualization code
most_opted=df.groupby('room_type')['calculated_host_listings_count'].count()
#sorting in descending order
most_opted_sorted=most_opted.sort_values(ascending=False)
print(most_opted_sorted)
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: calculated_host_listings_count, dtype: int64

# %%
# Plotting the figure
plt.figure(figsize=(10, 6))
# Plotting the bar chart
most_opted_sorted.plot(kind='bar', color='grey')

# Adding titles and labels
plt.title('Most opted room types')
plt.xlabel('Roomtype')
plt.ylabel('Total count')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(most_opted_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this particular chart because vertical bar charts are the best approach to show or highlight group or category comparisons.If it is further arranged in ascending order, it will be simpler for the observer to determine the outcome or gain the insight regarding which room type has been opted more.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above two graphs, it is evident that the entire room or apartment type of rooms have been selected by most of the people. The private room comes second in this list, and the shared room has the least number of sign-ins.\
# When we look into the dataset, we can confirm that there are 48895 listed properties, out of which 25409 are for the entire home/apt section, 22326 are for private rooms, and only 1160 are for shared rooms.\
# If we consider reviews as the number of people who visited a property, then we can say that about 580403 people reviewed or visited the entire home or apartment, 538346 visited the private room, and 19256 people visited the shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help in creating a positive business impact.
# This graph helps in analysing and understanding the nagatives or to find the reasons behind the trail in the business in the specified area and solve them accordingly.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
min_nightsrequred=df.groupby('room_type')['minimum_nights'].mean()
#sorting in descending order
min_nightsrequred_sorted=min_nightsrequred.sort_values(ascending=False)
print(min_nightsrequred_sorted)
# Out:
# room_type
# Entire home/apt    8.506907
# Shared room        6.475000
# Private room       5.377900
# Name: minimum_nights, dtype: float64

# %%
# Plotting the figure
plt.figure(figsize=(8, 6))
# Plotting the bar chart
min_nightsrequred_sorted.plot(kind='bar', color='grey')

# Adding titles and labels
plt.title('Average minimum nights')
plt.xlabel('Roomtype',fontsize='12',color='indigo')
plt.ylabel('Minimum nights to be paid for',fontsize='12',color='indigo')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(min_nightsrequred_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %%
# Chart - 9-a visualization code
minimum_nightsrequred = df.groupby('neighbourhood')['minimum_nights'].mean().reset_index()
#sorting in descending order
minimum_nightsrequred_sorted = minimum_nightsrequred.sort_values(by='minimum_nights', ascending=False)
print(minimum_nightsrequred_sorted.head(10))
# Out:
#                   neighbourhood  minimum_nights
# 184              Spuyten Duyvil       48.250000
# 146             North Riverdale       41.400000
# 6             Battery Park City       30.328571
# 149                   Olinville       23.500000
# 204                Vinegar Hill       18.352941
# 9    Bay Terrace, Staten Island       16.500000
# 136                  Mount Hope       15.950000
# 92            Greenwich Village       15.839286
# 137                 Murray Hill       15.589691
# 38            Claremont Village       15.214286

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(minimum_nightsrequred_sorted['neighbourhood'][:10],
               minimum_nightsrequred_sorted['minimum_nights'][:10],
               color='grey')

plt.xlabel('Neighbourhood')
plt.ylabel('Average Minimum Nights')
plt.title('Average Minimum Nights Required for Booking by Neighbourhood')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Chart - 9-b visualization code
minimum_nights_requred = df.groupby('neighbourhood_group')['minimum_nights'].mean().reset_index()
#sorting in descending order
minimum_nights_requred_sorted = minimum_nights_requred.sort_values(by='minimum_nights', ascending=False)
print(minimum_nights_requred_sorted.head(10))
# Out:
#   neighbourhood_group  minimum_nights
# 2           Manhattan        8.579151
# 1            Brooklyn        6.056556
# 3              Queens        5.181433
# 4       Staten Island        4.831099
# 0               Bronx        4.560953

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(minimum_nights_requred_sorted['neighbourhood_group'][:10],
               minimum_nights_requred_sorted['minimum_nights'][:10],
               color='grey')

plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Minimum Nights')
plt.title('Average Minimum Nights Required for Booking by Neighbourhood Group')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason I chose this specific chart is that vertical bar charts are the most effective way to depict or illustrate comparisons between groups or categories.If it is further arranged in ascending order, it will be simpler for the observer to determine the outcome or gain the insight regarding the minimum nights required to be paid for in order to acces a property.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By observing the first graph, it is clear that on average, one needs to pay at least for 8 to 9 days to book the property or access the property entirely, and you must pay for 6 to 7 days to rent a property that offers shared rooms, and for private rooms, the minimum nights to be paid for are about 5 to 6 days.
# When we analyse the second graph, we can confirm that people who need to stay longer can select properties from neighbourhoods, cities, or areas where the average of minimum nights to be paid for is high. \
# Looking into the third graph, we can confirm that which location has a high minimum days to be paid for in order to book the property.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It gives us a clear understanding of the average minimum number of nights required to be paid for in order to access the property.
# This helps in understanding the areas and places where marketing is needed.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
grouping= df.groupby(['neighbourhood_group', 'room_type']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouping.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Roomtypes by Neighbourhood groups')
plt.xlabel('Neighbourhood groups',fontsize='12')
plt.ylabel('Count',fontsize='12')
plt.legend(title='Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Comparing the prevalence of room types within each neighbourhood group is made simple with stacked bar charts. The segments within each bar indicate various room types, while each bar itself represents a neighbourhood group. This enables comparing the percentage of each type of room across several neighbourhood groupings easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart, we can confirm that in Bronx, Brooklyn, and Queens, private rooms are more listed or booked, and in Manhattan, entire homes or apartments are more preferred and shared room didn't get that importance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help in creating a positive business impact.\
# It helps in analysing the area of significance and makes us realise what kind of strategies work with respect to the above outcome. It helps us to understand the preferences in the neighbourhood groups.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10, 6))
sns.violinplot(hue='room_type', y='number_of_reviews', data=df)
plt.xlabel('Room Type')
plt.ylabel('Average Number of Reviews')
plt.title('Average Number of Reviews by Room Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
avg_no_of_reviews=df.groupby('room_type')['number_of_reviews'].mean()

avg_no_of_reviews_sorted=avg_no_of_reviews.sort_values(ascending=False)
print(avg_no_of_reviews_sorted)
# Out:
# room_type
# Private room       24.112962
# Entire home/apt    22.842418
# Shared room        16.600000
# Name: number_of_reviews, dtype: float64

# %%
# Plotting the figure
plt.figure(figsize=(10, 6))
avg_no_of_reviews_sorted.plot(kind='bar', color='grey')

plt.xlabel('Room Type',fontsize='12',color='indigo')
plt.ylabel('Average Number of Reviews',fontsize='12',color='indigo')
plt.title('Average Number of Reviews by Room Type')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(avg_no_of_reviews_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %%
sum_no_of_reviews=df.groupby('room_type')['number_of_reviews'].sum()

sum_no_of_reviews_sorted=sum_no_of_reviews.sort_values(ascending=False)
print(sum_no_of_reviews_sorted)
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %%
# Plotting the figure
plt.figure(figsize=(10, 6))
sum_no_of_reviews_sorted.plot(kind='bar', color='grey')

plt.xlabel('Room Type',fontsize='12',color='indigo')
plt.ylabel('Average Number of Reviews',fontsize='12',color='indigo')
plt.title('Sum of  Number of Reviews by Room Type')
plt.xticks(rotation=360)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding labels on top of each bar
for index, value in enumerate(sum_no_of_reviews_sorted):
    plt.text(index, value + 1, round(value, 2), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is a kind of visual aid that blends the characteristics of a kernel density plot and a box plot. It's frequently used to show how a numerical variable is distributed over several groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Analysing the first graph we can conclude that the average number of reviews of private rooms is high; it can be assumed that people who stayed in this property or rooms were happy with the services offered, if the reviews are positive. Even though the number of the reviews is not as high as the entire home or apartment kind of properties.\
# The entire home category falls along with the private room.\
# But for shared rooms, customer satisfaction is very low.\
# The next graphs confirms this.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help in creating a positive business impact.
# It helps in analysing the customer satisfaction level and solving the issue where customer satisfaction is less or very low. One can take various measures to improve the situation.

# %% [markdown]
# #### Chart - 12

# %%
#finding the sum of the number of reviews by host name
host_with_moost_reviews=df.groupby('host_name')['number_of_reviews'].sum().reset_index()
host_with_moost_reviews_sorted=host_with_moost_reviews.sort_values(by='number_of_reviews',ascending=False)
host_with_moost_reviews_sorted.head(10)
# Out:
#      host_name  number_of_reviews
# 7135   Michael              11081
# 2376     David               8103
# 4989      John               7223
# 4634     Jason               6522
# 314       Alex               6204
# 1931     Chris               5028
# 711       Anna               4799
# 3057      Eric               4733
# 2277    Daniel               4723
# 9213     Sarah               4579

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10, 6))

# Creating a bar chart with stacked bars (only one category here, but stacked if you have multiple categories)
plt.bar(host_with_moost_reviews_sorted['host_name'][:10], host_with_moost_reviews_sorted['number_of_reviews'][:10], color='grey')

plt.xlabel('Host Name',fontsize='12',color='indigo')
plt.ylabel('Number of Reviews',fontsize='12',color='indigo')
plt.title('Top 10 Hosts by Maximum Number of Reviews')
# plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For comparing values across several categories—in this case, the amount of reviews for every one of the top 10 hosts—bar charts are rather good. It's simple to compare each bar as each one stands for a host and shows the quantity of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Examinig the graph we can understand who has more reviews or the most preffered host in terms of service.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help in creating a positive business impact.
# This helps to focus on hosts who have fewer reviews and act accordingly to solve the issue.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
most_preferred_area = df.groupby(['neighbourhood'])['number_of_reviews'].max().reset_index()
sorted_most_preferred_area = most_preferred_area.sort_values(by='number_of_reviews', ascending=False)
most_preferred_areas = sorted_most_preferred_area.head(5)
print(most_preferred_areas)
# Out:
#        neighbourhood  number_of_reviews
# 105          Jamaica                629
# 94            Harlem                607
# 59     East Elmhurst                543
# 119  Lower East Side                540
# 151       Park Slope                488

# %%
plt.figure(figsize=(8, 6))
# Plotting the bar chart
# top_5_preferred_areas.plot(kind='bar', color='grey')
plt.bar(x='neighbourhood',height='number_of_reviews',data=most_preferred_areas,color='grey')

# Adding titles and labels
plt.xlabel('Neighbourhood',fontsize=15,color='indigo')
plt.ylabel('Number of Reviews',fontsize=15,color='indigo')
plt.title('Most prefered area',fontsize=15)
plt.tight_layout()
#For better visualization
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Charts work well for comparing values among several groups. In this instance, every bar stands for a neighbourhood and shows the count of reviews in that particular area. This facilitates the comparison of the popularity of several regions depending on the quantity of reviews they acquire.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph shows the areas with most reviews,  indicating their popularity among visitors.These places probably have great demand and draw a lot of people.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The amount of reviews in every neighbourhood could vary with time, indicating shifting visitor tastes or changes in travel patterns.Analysing such trends can enable property managers and hosts modify their plans to fit changing demand.
#
# Knowing which neighborhoods are the most preferred by guests, hosts and property managers can make informed decisions about where to invest in properties or allocate resources. Investing in popular areas can lead to increased occupancy rates and higher revenue potential.
#
# If the top 5 preferred areas are already saturated with listings, hosts may face increased competition, leading to downward pressure on prices and profitability. This could result in negative growth if hosts struggle to attract enough guests to maintain occupancy rates and revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
columns = ['price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']
required_data= df[columns]
new_column_names = ['Price', 'Minimum nights', 'Number of reviews', 'Host listings count', 'Availability']
required_data.columns = new_column_names

# Calculate correlation matrix
correlation_matrix = required_data.corr()

# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heat maps are best to display the relationship between two variables using colour intensity. It helps us to understand the outcome or result in the graph by analysing the colour and the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe both positive and negative corelation between various columns.
#
# **Price and Minimum Nights**: Here we can observe a correlation coefficient of 0.04,which indicates a weak positive relationship.But the relation is almost negligible.
#
# **Price and Number of Reviews**: Here we can observe a correlation coefficient of -0.05 which indicates a very weak negative relationship between the two variables.In detail,as the price slightly increases, the number of reviews slightly decreases, but the relation is almost negligible.
#
# **Price and  Host Listings Count**: Here we can observe a correlation coefficient of 0.06 which indicates a very weak positive relationship between the two variables.To explain it more, as the price slightly increases, the number of listings also slightly increases, but the effect is minimal.
#
# **Price and Availability**:  Here we can observe a correlation coefficient of 0.08 which indicates a very weak positive relationship between the two variables.To eloborate, as the price slightly increases, the availability also slightly increases, but the effect is minimal.
#
# **Minimum Nights and Number of Reviews**: Here we can observe a correlation coefficient of -0.08 which indicates a very weak negative relationship between the two variables.In other words, as the minimum nights slightly increase, the number of reviews slightly decreases, but the relation is almost negligible.
#
# **Minimum Nights and Host Listings Count**: Here we can observe a correlation coefficient of 0.13 which indicates a very weak positive relationship between the two variables.To explain it more, as the number of listings per host increases, there is a slight increase in the minimum nights required to stay at a particular listing.
#
# **Minimum Nights and Availability**: Here we can observe a correlation coefficient of 0.14 which indicates a very weak positive relationship between the two variables.In other words, as the minimum nights slightly increase, availability also slightly increases.
#
# **Number of Reviews and Host Listings Count**: Here we can observe a correlation coefficient of -0.07 which indicates a very weak negative relationship between the two variables.In other words, as the minimum nights slightly increase, the host listings countws slightly decreases, but the relation is almost negligible.
#
# **Number of Reviews and Availabilty**: Here we can observe a correlation coefficient of 0.17 which indicates a very weak positive relationship between the two variables.In other words, as the number of reviews slightly increase, availability also slightly increases.
#
# **Host Listings count and Availability**: Here we can observe a correlation coefficient of 0.23, which indicates a very weak positive relationship between the two variables.This means that as the host listings count increases, there is a slight increase in the minimum nights required to stay at a particular listing.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
columnss = ['price','number_of_reviews','availability_365']
required_datass= df[columnss]
new_columns_namess = ['Price', 'Number of reviews', 'Availability']
required_datass.columns = new_columns_namess

# Create pair plot
sns.pairplot(required_datass)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Particularly when considering many numerical variables, the pair plot visualisation provides a flexible and efficient instrument for investigating relationships and distributions between pairs of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot helps to show or understand the relationship between two variables simultaneously.
#
# From the above graph, we can understand the relation between the three variables, i.e., price, number of reviews, and availability. In the price vs. number of reviews graph, we can observe that if the price is high, the number of reviews is almost close to zero, and if the number of reviews is high, the price is close to zero.
#
# Analysing the price vs availability graph, the availability of the property varies. For the majority of the properties that have a lower price, the availability varies between 0 and 365. But for the properties that have a high price, we can see the minimal difference in the availability.
#
# In the graph of reviews vs availability, we can observe that the majority of the properties got reviews, and it is clear that reviews do not affect availability.

# %% [markdown]
# #### Chart - 16- Pair Plot

# %%
# Pair Plot visualization code
columns = ['price','calculated_host_listings_count']
required_datas= df[columns]
new_column_namess = ['Price', 'Host listings count']
required_datas.columns = new_column_namess

# Create pair plot
sns.pairplot(required_datas)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Particularly when considering many numerical variables, the pair plot visualisation provides a flexible and efficient instrument for investigating relationships and distributions between pairs of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the graph, it is evident that properties with a price below 5,000 are listed or selected the most.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 6))
plt.scatter(df['availability_365'], df['price'], alpha=0.5, color='black')
plt.xlabel('Availability (in days)')
plt.ylabel('price')
plt.title('Availability vs. price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter chart helps in understanding the distribution of the particular column or for the variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The availability is higher for the properties that have a lower price. There are proprties that have a lower price and are only available for a few days, and for the same category in price, the availability varies to about 350 days.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, important insights into the dynamics of the Airbnb ecosystem in New York City have been gained from the exploratory study of the Airbnb NYC 2019 dataset. We have developed a greater understanding of variables through a variety of visualisations, analyses, and visualisations. The knowledge acquired from these visualisations helps to improve user experiences for hosts, guests, policymakers, and industry stakeholders as well as to make strategic decisions and optimise operational plans, visualisation and analysis are highly beneficial. As a result, the firm as a whole performs better and profits rise.
#
# Data-driven decision-making, technology investment, ongoing monitoring, and data tracking are all critical, and the analysis clarified these points for us. Stakeholders may address societal and regulatory issues while advancing sustainable expansion of the Airbnb ecosystem by refining their plans and improving their products with an awareness of these insights.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
